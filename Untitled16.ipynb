# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonila7/Advance_Predictive_Analytics_Leonila/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Leonila7/Advance_Predictive_Analytics_Leonila/main/DJCA.csv")

# %%
df.head()
# Out:
#          DATE     DJCA
# 0  2013-12-06  5489.44
# 1  2013-12-09  5492.15
# 2  2013-12-10  5461.33
# 3  2013-12-11  5403.85
# 4  2013-12-12  5385.03

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985' ,freq='D')

# %%
time_series_data = pd.Series(range(1,11))

# %%
df.head()
# Out:
#          DATE     DJCA
# 0  2013-12-06  5489.44
# 1  2013-12-09  5492.15
# 2  2013-12-10  5461.33
# 3  2013-12-11  5403.85
# 4  2013-12-12  5385.03

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')


time_series_data = pd.Series(range(0,11))


df
# Out:
#             DATE      DJCA
# 0     2013-12-06   5489.44
# 1     2013-12-09   5492.15
# 2     2013-12-10   5461.33
# 3     2013-12-11   5403.85
# 4     2013-12-12   5385.03
# ...          ...       ...
# 2603  2023-11-29  11540.82
# 2604  2023-11-30  11693.90
# 2605  2023-12-01  11861.90
# 2606  2023-12-04  11865.03
# 2607  2023-12-05  11786.61
#
# [2608 rows x 2 columns]

# %%
import matplotlib.pyplot as plt


time_series_data_trend = time_series_data + 0.5 * pd.Series(range(0,11))


df
# Out:
#             DATE      DJCA
# 0     2013-12-06   5489.44
# 1     2013-12-09   5492.15
# 2     2013-12-10   5461.33
# 3     2013-12-11   5403.85
# 4     2013-12-12   5385.03
# ...          ...       ...
# 2603  2023-11-29  11540.82
# 2604  2023-11-30  11693.90
# 2605  2023-12-01  11861.90
# 2606  2023-12-04  11865.03
# 2607  2023-12-05  11786.61
#
# [2608 rows x 2 columns]
